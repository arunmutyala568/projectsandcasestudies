# %%
import pandas as pd

import numpy as np

from pandasql import sqldf as mysql

path1="https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv"

path2="https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv"

mydataframe1=pd.read_csv(path1,delimiter = ',')

mydataframe2=pd.read_csv(path2,sep=',')

headdatframe=mydataframe1.set_index("Country")

mydataframe1.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
mydataframe2.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
mydataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
mydataframe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
print(len(mydataframe1))

np.arange(0,len(mydataframe1))
# Out:
# 4656
# array([   0,    1,    2, ..., 4653, 4654, 4655])

# %%
mydataframe1.rename(columns={'Indicator':'indicator_id'},inplace=True)
mydataframe1.head(2)
# Out:
#                        indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
mydataframe1['PUBLISH STATES']='Publication Status'

mydataframe1.rename(columns={'PUBLISH STATES':'Publication status','WHO region':'WHO Region'},inplace=True)

mydataframe1.head(2)
# Out:
#                        indicator_id  Publication status  Year WHO Region  \
# 0  Life expectancy at birth (years)  Publication Status  1990     Europe
# 1  Life expectancy at birth (years)  Publication Status  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
mydataframe1.columns
# Out:
# Index(['indicator_id', 'Publication status', 'Year', 'WHO Region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
mydataframe1.sort_values(by='Year',ascending=True,inplace=True)

mydataframe1.head()
# Out:
#                            indicator_id  Publication status  Year WHO Region  \
# 0      Life expectancy at birth (years)  Publication Status  1990     Europe
# 1270   Life expectancy at birth (years)  Publication Status  1990     Europe
# 3193   Life expectancy at birth (years)  Publication Status  1990     Europe
# 3194   Life expectancy at birth (years)  Publication Status  1990     Europe
# 3197  Life expectancy at age 60 (years)  Publication Status  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# ...

# %%
mydataframe1.sort_values(by=['Year','Country','WHO Region','Publication status'],ascending=True,inplace=True)

mydataframe1
# Out:
#                                          indicator_id  Publication status  \
# 1395                Life expectancy at age 60 (years)  Publication Status
# 965                  Life expectancy at birth (years)  Publication Status
# 2959                Life expectancy at age 60 (years)  Publication Status
# 1792                 Life expectancy at birth (years)  Publication Status
# 554                  Life expectancy at birth (years)  Publication Status
# 555                 Life expectancy at age 60 (years)  Publication Status
# 3113                 Life expectancy at birth (years)  Publication Status
# 3114                Life expectancy at age 60 (years)  Publication Status
# 1931                Life expectancy at age 60 (years)  Publication Status
# 1522                Life expectancy at age 60 (years)  Publication Status
# 689                  Life expectancy at birth (years)  Publication Status
# 299                  Life expectancy at birth (years)  Publication Status
# ...

# %%
headdataframe.reset_index()
# Out:
#           Country                                     indicator_id  \
# 0     Afghanistan                Life expectancy at age 60 (years)
# 1     Afghanistan                Life expectancy at age 60 (years)
# 2     Afghanistan                 Life expectancy at birth (years)
# 3     Afghanistan                 Life expectancy at birth (years)
# 4     Afghanistan                Life expectancy at age 60 (years)
# 5     Afghanistan                 Life expectancy at birth (years)
# 6         Albania                 Life expectancy at birth (years)
# 7         Albania                 Life expectancy at birth (years)
# 8         Albania                Life expectancy at age 60 (years)
# 9         Albania                Life expectancy at age 60 (years)
# 10        Albania                Life expectancy at age 60 (years)
# 11        Albania                 Life expectancy at birth (years)
# 12        Algeria                Life expectancy at age 60 (years)
# ...

# %%
np.array(mydataframe1['WHO Region'])
# Out:
# array(['Eastern Mediterranean', 'Eastern Mediterranean',
#        'Eastern Mediterranean', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
mydataframe1.loc[[11,24,37]]
# Out:
#                          indicator_id  Publication status  Year  \
# 11   Life expectancy at birth (years)  Publication Status  2012
# 24  Life expectancy at age 60 (years)  Publication Status  2012
# 37  Life expectancy at age 60 (years)  Publication Status  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %%
usersdataframe=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')

usersdataframe
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessionsdataframe=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')

sessionsdataframe
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
productsdataframe=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')

productsdataframe
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactionsdataframe=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

transactionsdataframe
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
mysql("""select 

         transactionsdataframe.TransactionID,transactionsdataframe.TransactionDate,transactionsdataframe.UserID,

         transactionsdataframe.ProductID,transactionsdataframe.Quantity,usersdataframe.User,usersdataframe.Gender,usersdataframe.Registered,
         
         usersdataframe.Cancelled
         
         from transactionsdataframe 
         
         LEFT JOIN usersdataframe on transactionsdataframe.UserID=usersdataframe.UserID""")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1      None
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3      None
# 8              9      2015-04-24     7.0          4         3      None
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0    None        None        None
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21        None
# ...

# %%
mysql("""SELECT transactionsdataframe.TransactionID,transactionsdataframe.TransactionDate,transactionsdataframe.ProductID,transactionsdataframe.UserID
        ,transactionsdataframe.Quantity FROM transactionsdataframe
          WHERE NOT EXISTS
           (SELECT *
            FROM usersdataframe
            WHERE usersdataframe.UserID= transactionsdataframe.UserID
            )""")
# Out:
#    TransactionID TransactionDate  ProductID  UserID  Quantity
# 0              1      2010-08-21          2     7.0         1
# 1              8      2014-04-24          2     NaN         3
# 2              9      2015-04-24          4     7.0         3

# %%
mysql("""SELECT   transactionsdataframe.TransactionID,transactionsdataframe.TransactionDate,transactionsdataframe.UserID,

         transactionsdataframe.ProductID,transactionsdataframe.Quantity,usersdataframe.User,usersdataframe.Gender,usersdataframe.Registered,
         
         usersdataframe.Cancelled
         FROM transactionsdataframe
         INNER JOIN usersdataframe ON transactionsdataframe.UserID = usersdataframe.UserID ORDER BY User
         ;
""")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21        None
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
mysql("""SELECT *
          FROM transactionsdataframe
          FULL OUTER JOIN usersdataframe
          ON transactionsdataframe.UserID= usersdataframe.UserID
          ORDER BY usersdataframe.User ;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     551     def do_execute(self, cursor, statement, parameters, context=None):
# --> 552         cursor.execute(statement, parameters)
#     553
#
# OperationalError: RIGHT and FULL OUTER JOINs are not currently supported
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...
